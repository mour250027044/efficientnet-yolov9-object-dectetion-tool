# %%
# !pip install PyDrive2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 84.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 101.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [PyDrive2]/11 [PyDrive2]i-python-client]
# ...

# %%
import shutil

# Replace 'ultralyticsWithEfficientNetB3' with your folder name
shutil.make_archive("project_backup", "zip", "ultralyticsWithEfficientNetB3")
# Out:
# '/home/250027044/ultralyticsWithEfficientNetB3/project_backup.zip'

# %%
# !pip install gdown

# %%
import gdown

file_path = "/home/250027044/ultralyticsWithEfficientNetB3/project_backup.zip"
gdown.upload(file_path, quiet=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 4
#       1 import gdown
#       3 file_path = '/home/250027044/ultralyticsWithEfficientNetB3/project_backup.zip'
# ----> 4 gdown.upload(file_path, quiet=False)
#
# AttributeError: module 'gdown' has no attribute 'upload'

# %%
# This uploads the file to a secure temporary link (valid for 14 days)
# !curl --upload-file ./project_backup.zip https://transfer.sh/project_backup.zip
# Out:
# curl: (7) Failed to connect to transfer.sh port 443 after 3844 ms: Couldn't connect to server

# %%
# Set your identity
# !git config --global user.email "250027044@aston.ac.uk"
# !git config --global user.name "mour250027044"

# Initialize the repo
# !git init
# Out:
# Reinitialized existing Git repository in /home/250027044/ultralyticsWithEfficientNetB3/.git/
